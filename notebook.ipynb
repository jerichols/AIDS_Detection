# %% [markdown]
# **Mengimpor Modul untuk Menjalankan Pipeline TFX dengan Apache Beam**
#
# Kode ini mengimpor modul `os`, `components`, dan `pipeline` dari folder `modules`, serta `BeamDagRunner` dari `tfx.orchestration.beam.beam_dag_runner`. Fungsinya adalah untuk mengatur dan menjalankan pipeline TFX menggunakan runner Beam, yang memungkinkan eksekusi pipeline pada berbagai backend yang didukung oleh Apache Beam.

# %%
import os
from modules import components, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

# %% [markdown]
# **Mengatur Parameter dan Path untuk Pipeline TFX**
#
# Kode ini menetapkan nama pipeline, menentukan path untuk data input, modul transformasi, modul tuner, dan modul pelatihan, serta menentukan path untuk output pipeline seperti model yang telah dilayani dan metadata. Fungsinya adalah untuk mengonfigurasi dan menyiapkan parameter yang diperlukan untuk komponen pipeline TFX, yang akan digunakan saat pipeline dijalankan.

# %%
PIPELINE_NAME = "jericho_luthfi_ihFK-pipeline"

# Pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/transform.py"
TUNER_MODULE_FILE = "modules/tuner.py"
TRAINER_MODULE_FILE = "modules/trainer.py"

# Pipeline outputs
OUTPUT_BASE = "output"

serving_model_dir = os.path.join(OUTPUT_BASE, "serving_model")
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# Parameter untuk komponen
components_args = {
    "data_dir": DATA_ROOT,
    "transform_module": TRANSFORM_MODULE_FILE,
    "training_module": TRAINER_MODULE_FILE,
    "tuner_module": TUNER_MODULE_FILE,
    "training_steps": 1000,
    "eval_steps": 800,
    "serving_model_dir": serving_model_dir,
}

# %% [markdown]
# **Inisialisasi Komponen Pipeline TFX**
#
# Kode ini memanggil fungsi `init_components` dari modul `components` dengan argumen yang ditentukan dalam `components_args`. Fungsinya adalah untuk menginisialisasi semua komponen yang diperlukan untuk pipeline TFX berdasarkan konfigurasi yang telah disiapkan sebelumnya.

# %%
komponen = components.init_components(**components_args)

# %% [markdown]
# **Menjalankan Pipeline TFX dengan Apache Beam**
#
# Kode ini menginisialisasi objek pipeline TFX dengan memanggil `init_pipeline` dari modul `pipeline`, menggunakan parameter seperti `pipeline_root`, `pipeline_name`, `metadata_path`, dan komponen yang telah diinisialisasi. Kemudian, pipeline dijalankan menggunakan `BeamDagRunner`, yang mengeksekusi pipeline pada backend yang didukung oleh Apache Beam.

# %%
pipeline_obj = pipeline.init_pipeline(
    pipeline_root=pipeline_root,
    pipeline_name=PIPELINE_NAME,
    metadata_path=metadata_path,
    components=komponen
)

BeamDagRunner().run(pipeline=pipeline_obj)
# Out:
# Trial 10 Complete [00h 00m 25s]
# binary_accuracy: 0.9370156526565552
#
# Best binary_accuracy So Far: 0.9824374914169312
# Total elapsed time: 00h 02m 45s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Int', 'config': {'name': 'n_layers', 'default': None, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': None}}, {'class_name': 'Int', 'config': {'name': 'dense_units', 'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 32, 'sampling': None}}, {'class_name': 'Choice', 'config': {'name': 'lr', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}], 'values': {'n_layers': 5, 'dense_units': 80, 'lr': 0.001, 'tuner/epochs': 5, 'tuner/initial_epoch': 2, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0002'}}
# INFO:absl:Best Hyperparameters are written to output\jericho_luthfi_ihFK-pipeline\Tuner\best_hyperparameters\18\best_hyperparameters.txt.
# INFO:absl:Tuner results are written to output\jericho_luthfi_ihFK-pipeline\Tuner\tuner_results\18\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 18 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'tuner_results': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Tuner\\tuner_results\\18"
# , artifact_type: name: "TunerResults"
# )], 'best_hyperparameters': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Tuner\\best_hyperparameters\\18"
# , artifact_type: name: "HyperParameters"
# )]}) for execution 18
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Tuner is finished.
# Results summary
# Results in output\jericho_luthfi_ihFK-pipeline\Tuner\.system\executor_execution\18\.temp\18\kt_hyperband
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000002723A7AF8E0>
# Trial summary
# Hyperparameters:
# n_layers: 5
# dense_units: 80
# lr: 0.001
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0002
# Score: 0.9824374914169312
# Trial summary
# Hyperparameters:
# n_layers: 5
# dense_units: 80
# lr: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9672187566757202
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 80
# lr: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9546718597412109
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 48
# lr: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0004
# Score: 0.951296865940094
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 48
# lr: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.938156247138977
# Trial summary
# Hyperparameters:
# n_layers: 4
# dense_units: 48
# lr: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9370156526565552
# Trial summary
# Hyperparameters:
# n_layers: 1
# dense_units: 80
# lr: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.8959218859672546
# Trial summary
# Hyperparameters:
# n_layers: 1
# dense_units: 16
# lr: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.8947968482971191
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 80
# lr: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.8802656531333923
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 48
# lr: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.8618749976158142
# INFO:absl:node Evaluator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240717-152230.770349"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"infected\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"trt\",\n        \"drugs\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Evaluator] Resolved inputs: ({'model': [Artifact(artifact: id: 29
# type_id: 30
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\17"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721204699974
# last_update_time_since_epoch: 1721204699974
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': [Artifact(artifact: id: 15
# type_id: 30
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721203383517
# last_update_time_since_epoch: 1721203383517
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "output\\jericho_luthfi_ihFK-pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:142796,xor_checksum:1721199902,sum_checksum:1721199902"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721202626715
# last_update_time_since_epoch: 1721202626715
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 19
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=19, input_dict={'model': [Artifact(artifact: id: 29
# type_id: 30
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\17"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721204699974
# last_update_time_since_epoch: 1721204699974
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': [Artifact(artifact: id: 15
# type_id: 30
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721203383517
# last_update_time_since_epoch: 1721203383517
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "output\\jericho_luthfi_ihFK-pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:142796,xor_checksum:1721199902,sum_checksum:1721199902"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721202626715
# last_update_time_since_epoch: 1721202626715
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]}, output_dict=defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\evaluation\\19"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\blessing\\19"
# , artifact_type: name: "ModelBlessing"
# )]}), exec_properties={'example_splits': 'null', 'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "infected"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "trt",\n        "drugs"\n      ]\n    }\n  ]\n}'}, execution_output_uri='output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\.system\\executor_execution\\19\\executor_output.pb', stateful_working_dir='output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\.system\\stateful_working_dir\\20240717-152230.770349', tmp_dir='output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\.system\\executor_execution\\19\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240717-152230.770349"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"infected\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"trt\",\n        \"drugs\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "jericho_luthfi_ihFK-pipeline"
# , pipeline_run_id='20240717-152230.770349')
# INFO:absl:udf_utils.get_fn {'example_splits': 'null', 'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "infected"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "trt",\n        "drugs"\n      ]\n    }\n  ]\n}'} 'custom_eval_shared_model'
# INFO:absl:Adding default baseline ModelSpec based on the candidate ModelSpec provided. The candidate model will be called "candidate" and the baseline will be called "baseline": updated_config=
# model_specs {
#   name: "candidate"
#   label_key: "infected"
# }
# model_specs {
#   name: "baseline"
#   label_key: "infected"
#   is_baseline: true
# }
# slicing_specs {
# }
# slicing_specs {
#   feature_keys: "trt"
#   feature_keys: "drugs"
# }
# metrics_specs {
#   metrics {
#     class_name: "AUC"
#   }
#   metrics {
#     class_name: "Precision"
#   }
#   metrics {
#     class_name: "Recall"
#   }
#   metrics {
#     class_name: "ExampleCount"
#   }
#   metrics {
#     class_name: "BinaryAccuracy"
#     threshold {
#       value_threshold {
#         lower_bound {
#           value: 0.5
#         }
#       }
#       change_threshold {
#         absolute {
#           value: 0.0001
#         }
#         direction: HIGHER_IS_BETTER
#       }
#     }
#   }
# }
#
# INFO:absl:Using output\jericho_luthfi_ihFK-pipeline\Trainer\model\17\Format-Serving as candidate model.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002723BA5A4C0> and <keras.engine.input_layer.InputLayer object at 0x00000272892F7760>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002723BA5A4C0> and <keras.engine.input_layer.InputLayer object at 0x00000272892F7760>).
# INFO:absl:Using output\jericho_luthfi_ihFK-pipeline\Trainer\model\8\Format-Serving as baseline model.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027253E6DB80> and <keras.engine.input_layer.InputLayer object at 0x000002724306B130>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027253E6DB80> and <keras.engine.input_layer.InputLayer object at 0x000002724306B130>).
# INFO:absl:The 'example_splits' parameter is not set, using 'eval' split.
# INFO:absl:Evaluating model.
# INFO:absl:udf_utils.get_fn {'example_splits': 'null', 'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "infected"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "trt",\n        "drugs"\n      ]\n    }\n  ]\n}'} 'custom_extractors'
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027253F12490> and <keras.engine.input_layer.InputLayer object at 0x000002725AF112B0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027253F12490> and <keras.engine.input_layer.InputLayer object at 0x000002725AF112B0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027250970760> and <keras.engine.input_layer.InputLayer object at 0x000002723FAA6340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027250970760> and <keras.engine.input_layer.InputLayer object at 0x000002723FAA6340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002725D20CE50> and <keras.engine.input_layer.InputLayer object at 0x000002724C5685E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002725D20CE50> and <keras.engine.input_layer.InputLayer object at 0x000002724C5685E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002725E212520> and <keras.engine.input_layer.InputLayer object at 0x000002723A7D7AF0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002725E212520> and <keras.engine.input_layer.InputLayer object at 0x000002723A7D7AF0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027242FE50A0> and <keras.engine.input_layer.InputLayer object at 0x000002723B85BD30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027242FE50A0> and <keras.engine.input_layer.InputLayer object at 0x000002723B85BD30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000272741416D0> and <keras.engine.input_layer.InputLayer object at 0x00000272669E4910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000272741416D0> and <keras.engine.input_layer.InputLayer object at 0x00000272669E4910>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000272657553A0> and <keras.engine.input_layer.InputLayer object at 0x00000272945BCDC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000272657553A0> and <keras.engine.input_layer.InputLayer object at 0x00000272945BCDC0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027249252FA0> and <keras.engine.input_layer.InputLayer object at 0x0000027265738C40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027249252FA0> and <keras.engine.input_layer.InputLayer object at 0x0000027265738C40>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002723BE6B940> and <keras.engine.input_layer.InputLayer object at 0x0000027249246B50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002723BE6B940> and <keras.engine.input_layer.InputLayer object at 0x0000027249246B50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027296B8C520> and <keras.engine.input_layer.InputLayer object at 0x000002723BE79B50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027296B8C520> and <keras.engine.input_layer.InputLayer object at 0x000002723BE79B50>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027262501A60> and <keras.engine.input_layer.InputLayer object at 0x000002723D4F7370>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027262501A60> and <keras.engine.input_layer.InputLayer object at 0x000002723D4F7370>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027297577640> and <keras.engine.input_layer.InputLayer object at 0x000002728956E8E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027297577640> and <keras.engine.input_layer.InputLayer object at 0x000002728956E8E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027297E54F70> and <keras.engine.input_layer.InputLayer object at 0x0000027297E4F490>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027297E54F70> and <keras.engine.input_layer.InputLayer object at 0x0000027297E4F490>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027298791B80> and <keras.engine.input_layer.InputLayer object at 0x0000027297D6A850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027298791B80> and <keras.engine.input_layer.InputLayer object at 0x0000027297D6A850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027298F67850> and <keras.engine.input_layer.InputLayer object at 0x000002729877F760>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027298F67850> and <keras.engine.input_layer.InputLayer object at 0x000002729877F760>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027299724820> and <keras.engine.input_layer.InputLayer object at 0x0000027298F56430>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000027299724820> and <keras.engine.input_layer.InputLayer object at 0x0000027298F56430>).
# c:\Users\ANANG\ML_Ops\myenv\lib\site-packages\tensorflow_model_analysis\metrics\confusion_matrix_metrics.py:521: RuntimeWarning: invalid value encountered in true_divide
#   recall = tp / (tp + fn)
# INFO:absl:Evaluation complete. Results written to output\jericho_luthfi_ihFK-pipeline\Evaluator\evaluation\19.
# INFO:absl:Checking validation results.
# WARNING:tensorflow:From c:\Users\ANANG\ML_Ops\myenv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From c:\Users\ANANG\ML_Ops\myenv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:absl:Blessing result False written to output\jericho_luthfi_ihFK-pipeline\Evaluator\blessing\19.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 19 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\evaluation\\19"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\blessing\\19"
# , artifact_type: name: "ModelBlessing"
# )]}) for execution 19
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Evaluator is finished.
# INFO:absl:node Pusher is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240717-152230.770349"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Pusher] Resolved inputs: ({'model': [Artifact(artifact: id: 29
# type_id: 30
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\17"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721204699974
# last_update_time_since_epoch: 1721204699974
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 33
# type_id: 33
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\blessing\\19"
# custom_properties {
#   key: "baseline_model"
#   value {
#     string_value: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "baseline_model_id"
#   value {
#     int_value: 15
#   }
# }
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\17"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 29
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721204909931
# last_update_time_since_epoch: 1721204909931
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 20
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=20, input_dict={'model': [Artifact(artifact: id: 29
# type_id: 30
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\17"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721204699974
# last_update_time_since_epoch: 1721204699974
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 33
# type_id: 33
# uri: "output\\jericho_luthfi_ihFK-pipeline\\Evaluator\\blessing\\19"
# custom_properties {
#   key: "baseline_model"
#   value {
#     string_value: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "baseline_model_id"
#   value {
#     int_value: 15
#   }
# }
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\jericho_luthfi_ihFK-pipeline\\Trainer\\model\\17"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 29
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721204909931
# last_update_time_since_epoch: 1721204909931
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]}, output_dict=defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Pusher\\pushed_model\\20"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}), exec_properties={'custom_config': 'null', 'push_destination': '{\n  "filesystem": {\n    "base_directory": "output\\\\serving_model"\n  }\n}'}, execution_output_uri='output\\jericho_luthfi_ihFK-pipeline\\Pusher\\.system\\executor_execution\\20\\executor_output.pb', stateful_working_dir='output\\jericho_luthfi_ihFK-pipeline\\Pusher\\.system\\stateful_working_dir\\20240717-152230.770349', tmp_dir='output\\jericho_luthfi_ihFK-pipeline\\Pusher\\.system\\executor_execution\\20\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240717-152230.770349"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "jericho_luthfi_ihFK-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240717-152230.770349"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "jericho_luthfi_ihFK-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "jericho_luthfi_ihFK-pipeline"
# , pipeline_run_id='20240717-152230.770349')
# INFO:absl:Model on output\jericho_luthfi_ihFK-pipeline\Evaluator\blessing\19 was not blessed by model validation
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 20 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\jericho_luthfi_ihFK-pipeline\\Pusher\\pushed_model\\20"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}) for execution 20
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Pusher is finished.
